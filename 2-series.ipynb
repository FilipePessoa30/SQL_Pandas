# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

# %%
labels = ['a', 'b', 'c']

minha_lista = [10, 20, 30]

arr = np.array([10, 20, 30])

d = {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(data=labels, index=minha_lista)
# Out:
# 10    a
# 20    b
# 30    c
# dtype: object

# %%
pd.Series(labels, minha_lista)
# Out:
# 10    a
# 20    b
# 30    c
# dtype: object

# %%
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1 = pd.Series([1, 2, 3, 4], ['USA', 'Germany', 'USSR', 'Japan'])

# %%
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2 = pd.Series([1, 2, 5, 4], ['USA', 'Germany', 'Italy', 'Japan'])

# %%
ser2
# Out:
# USA        1
# Germany    2
# Italy      5
# Japan      4
# dtype: int64

# %%
ser1['USA']
# Out:
# 1

# %%
ser1['Germany']
# Out:
# 2

# %%
ser1[['Germany', 'Japan']]
# Out:
# Germany    2
# Japan      4
# dtype: int64

# %%
ser1 + ser2
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %% [markdown]
# ## Data Frames

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(randn(5, 4), ['A', 'B', 'C', 'D', 'E'], ['W', 'X', 'Y', 'Z'])

# %%
df
# Out:
#           W         X         Y         Z
# A -0.385944 -0.495023  0.317290  0.141632
# B -1.516287 -2.292915  0.711454  0.119752
# C  0.597146  0.088397 -1.622199 -2.385858
# D -0.143639 -0.810150 -2.557446  0.858009
# E -0.418809  0.349715  1.188413 -1.030944

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['W'] # Padrão série
# Out:
# A   -0.385944
# B   -1.516287
# C    0.597146
# D   -0.143639
# E   -0.418809
# Name: W, dtype: float64

# %%
df[['W']]  #Padrão data frame
# Out:
#           W
# A -0.385944
# B -1.516287
# C  0.597146
# D -0.143639
# E -0.418809

# %%
df['new'] = df['W'] + df['Y']

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.385944 -0.495023  0.317290  0.141632 -0.068654
# B -1.516287 -2.292915  0.711454  0.119752 -0.804833
# C  0.597146  0.088397 -1.622199 -2.385858 -1.025053
# D -0.143639 -0.810150 -2.557446  0.858009 -2.701085
# E -0.418809  0.349715  1.188413 -1.030944  0.769604

# %%
df.drop('new', axis =1)
# Out:
#           W         X         Y         Z
# A -0.385944 -0.495023  0.317290  0.141632
# B -1.516287 -2.292915  0.711454  0.119752
# C  0.597146  0.088397 -1.622199 -2.385858
# D -0.143639 -0.810150 -2.557446  0.858009
# E -0.418809  0.349715  1.188413 -1.030944

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.385944 -0.495023  0.317290  0.141632 -0.068654
# B -1.516287 -2.292915  0.711454  0.119752 -0.804833
# C  0.597146  0.088397 -1.622199 -2.385858 -1.025053
# D -0.143639 -0.810150 -2.557446  0.858009 -2.701085
# E -0.418809  0.349715  1.188413 -1.030944  0.769604

# %%
df2 = df.drop('new', axis=1)

# %%
df2
# Out:
#           W         X         Y         Z
# A -0.385944 -0.495023  0.317290  0.141632
# B -1.516287 -2.292915  0.711454  0.119752
# C  0.597146  0.088397 -1.622199 -2.385858
# D -0.143639 -0.810150 -2.557446  0.858009
# E -0.418809  0.349715  1.188413 -1.030944

# %%
df.drop('new', axis=1, inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A -0.385944 -0.495023  0.317290  0.141632
# B -1.516287 -2.292915  0.711454  0.119752
# C  0.597146  0.088397 -1.622199 -2.385858
# D -0.143639 -0.810150 -2.557446  0.858009
# E -0.418809  0.349715  1.188413 -1.030944

# %%
df.loc['A']
# Out:
# W   -0.385944
# X   -0.495023
# Y    0.317290
# Z    0.141632
# Name: A, dtype: float64

# %%
df.iloc[0]
# Out:
# W   -0.385944
# X   -0.495023
# Y    0.317290
# Z    0.141632
# Name: A, dtype: float64

# %%
df.loc[['A', 'B'], ['W', 'Y']]
# Out:
#           W         Y
# A -0.385944  0.317290
# B -1.516287  0.711454

# %%
df > 0
# Out:
#        W      X      Y      Z
# A  False  False   True   True
# B  False  False   True   True
# C   True   True  False  False
# D  False  False  False   True
# E  False   True   True  False

# %%
df[df > 0]
# Out:
#           W         X         Y         Z
# A       NaN       NaN  0.317290  0.141632
# B       NaN       NaN  0.711454  0.119752
# C  0.597146  0.088397       NaN       NaN
# D       NaN       NaN       NaN  0.858009
# E       NaN  0.349715  1.188413       NaN

# %%
df['Y'] > 0
# Out:
# A     True
# B     True
# C    False
# D    False
# E     True
# Name: Y, dtype: bool

# %%
df[df['Y']> 0]
# Out:
#           W         X         Y         Z
# A -0.385944 -0.495023  0.317290  0.141632
# B -1.516287 -2.292915  0.711454  0.119752
# E -0.418809  0.349715  1.188413 -1.030944

# %%
(df['Y']> 0 ) & (df['X'] > 0)
# Out:
# A    False
# B    False
# C    False
# D    False
# E     True
# dtype: bool

# %%
df[(df['Y']> 0 ) & (df['X'] > 0)]
# Out:
#           W         X         Y         Z
# E -0.418809  0.349715  1.188413 -1.030944

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df.reset_index()
df.reset_index(inplace=True) # A mudança se torna permanente

# %%
df
# Out:
#   index         W         X         Y         Z
# 0     A -0.385944 -0.495023  0.317290  0.141632
# 1     B -1.516287 -2.292915  0.711454  0.119752
# 2     C  0.597146  0.088397 -1.622199 -2.385858
# 3     D -0.143639 -0.810150 -2.557446  0.858009
# 4     E -0.418809  0.349715  1.188413 -1.030944

# %%
df.set_index('index', inplace=True) # restaura o index a partir de uma coluna

# %%
df
# Out:
#               W         X         Y         Z
# index
# A     -0.385944 -0.495023  0.317290  0.141632
# B     -1.516287 -2.292915  0.711454  0.119752
# C      0.597146  0.088397 -1.622199 -2.385858
# D     -0.143639 -0.810150 -2.557446  0.858009
# E     -0.418809  0.349715  1.188413 -1.030944

# %%
novoInd = 'CA NY WY OR CO'.split()

# %%
df['novoInd'] = novoInd

# %%
df.reset_index().set_index('novoInd')
# Out:
#         index         W         X         Y         Z
# novoInd
# CA          A -0.385944 -0.495023  0.317290  0.141632
# NY          B -1.516287 -2.292915  0.711454  0.119752
# WY          C  0.597146  0.088397 -1.622199 -2.385858
# OR          D -0.143639 -0.810150 -2.557446  0.858009
# CO          E -0.418809  0.349715  1.188413 -1.030944
