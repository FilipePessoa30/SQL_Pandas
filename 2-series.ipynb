# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

# %%
labels = ['a', 'b', 'c']

minha_lista = [10, 20, 30]

arr = np.array([10, 20, 30])

d = {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(data=labels, index=minha_lista)
# Out:
# 10    a
# 20    b
# 30    c
# dtype: object

# %%
pd.Series(labels, minha_lista)
# Out:
# 10    a
# 20    b
# 30    c
# dtype: object

# %%
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1 = pd.Series([1, 2, 3, 4], ['USA', 'Germany', 'USSR', 'Japan'])

# %%
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2 = pd.Series([1, 2, 5, 4], ['USA', 'Germany', 'Italy', 'Japan'])

# %%
ser2
# Out:
# USA        1
# Germany    2
# Italy      5
# Japan      4
# dtype: int64

# %%
ser1['USA']
# Out:
# 1

# %%
ser1['Germany']
# Out:
# 2

# %%
ser1[['Germany', 'Japan']]
# Out:
# Germany    2
# Japan      4
# dtype: int64

# %%
ser1 + ser2
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %% [markdown]
# ## Data Frames

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(randn(5, 4), ['A', 'B', 'C', 'D', 'E'], ['W', 'X', 'Y', 'Z'])

# %%
df
# Out:
#           W         X         Y         Z
# A -0.487043  0.292458 -0.029252 -0.226895
# B -0.175181 -0.648093 -0.081850 -0.208764
# C -0.367467  0.506700  0.720512 -0.557971
# D  0.009223  0.331336  0.127649  0.482931
# E  0.694884  0.306148 -1.031188 -0.156282

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['W'] # Padrão série
# Out:
# A   -0.487043
# B   -0.175181
# C   -0.367467
# D    0.009223
# E    0.694884
# Name: W, dtype: float64

# %%
df[['W']]  #Padrão data frame
# Out:
#           W
# A -0.487043
# B -0.175181
# C -0.367467
# D  0.009223
# E  0.694884

# %%
df['new'] = df['W'] + df['Y']

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.487043  0.292458 -0.029252 -0.226895 -0.516295
# B -0.175181 -0.648093 -0.081850 -0.208764 -0.257031
# C -0.367467  0.506700  0.720512 -0.557971  0.353045
# D  0.009223  0.331336  0.127649  0.482931  0.136873
# E  0.694884  0.306148 -1.031188 -0.156282 -0.336304

# %%
df.drop('new', axis =1)
# Out:
#           W         X         Y         Z
# A -0.487043  0.292458 -0.029252 -0.226895
# B -0.175181 -0.648093 -0.081850 -0.208764
# C -0.367467  0.506700  0.720512 -0.557971
# D  0.009223  0.331336  0.127649  0.482931
# E  0.694884  0.306148 -1.031188 -0.156282

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.487043  0.292458 -0.029252 -0.226895 -0.516295
# B -0.175181 -0.648093 -0.081850 -0.208764 -0.257031
# C -0.367467  0.506700  0.720512 -0.557971  0.353045
# D  0.009223  0.331336  0.127649  0.482931  0.136873
# E  0.694884  0.306148 -1.031188 -0.156282 -0.336304

# %%
df2 = df.drop('new', axis=1)

# %%
df2
# Out:
#           W         X         Y         Z
# A -0.487043  0.292458 -0.029252 -0.226895
# B -0.175181 -0.648093 -0.081850 -0.208764
# C -0.367467  0.506700  0.720512 -0.557971
# D  0.009223  0.331336  0.127649  0.482931
# E  0.694884  0.306148 -1.031188 -0.156282

# %%
df.drop('new', axis=1, inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A -0.487043  0.292458 -0.029252 -0.226895
# B -0.175181 -0.648093 -0.081850 -0.208764
# C -0.367467  0.506700  0.720512 -0.557971
# D  0.009223  0.331336  0.127649  0.482931
# E  0.694884  0.306148 -1.031188 -0.156282

# %%
df.loc['A']
# Out:
# W   -0.487043
# X    0.292458
# Y   -0.029252
# Z   -0.226895
# Name: A, dtype: float64

# %%
df.iloc[0]
# Out:
# W   -0.487043
# X    0.292458
# Y   -0.029252
# Z   -0.226895
# Name: A, dtype: float64

# %%
df.loc[['A', 'B'], ['W', 'Y']]
# Out:
#           W         Y
# A -0.487043 -0.029252
# B -0.175181 -0.081850

# %%
df > 0
# Out:
#        W      X      Y      Z
# A  False   True  False  False
# B  False  False  False  False
# C  False   True   True  False
# D   True   True   True   True
# E   True   True  False  False

# %%
df[df > 0]
# Out:
#           W         X         Y         Z
# A       NaN  0.292458       NaN       NaN
# B       NaN       NaN       NaN       NaN
# C       NaN  0.506700  0.720512       NaN
# D  0.009223  0.331336  0.127649  0.482931
# E  0.694884  0.306148       NaN       NaN

# %%
df['Y'] > 0
# Out:
# A    False
# B    False
# C     True
# D     True
# E    False
# Name: Y, dtype: bool

# %%
df[df['Y']> 0]
# Out:
#           W         X         Y         Z
# C -0.367467  0.506700  0.720512 -0.557971
# D  0.009223  0.331336  0.127649  0.482931

# %%
(df['Y']> 0 ) & (df['X'] > 0)
# Out:
# A    False
# B    False
# C     True
# D     True
# E    False
# dtype: bool

# %%
df[(df['Y']> 0 ) & (df['X'] > 0)]
# Out:
#           W         X         Y         Z
# C -0.367467  0.506700  0.720512 -0.557971
# D  0.009223  0.331336  0.127649  0.482931
