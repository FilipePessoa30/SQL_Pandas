# %% [markdown]
# # Hierarquia de índices e índices múltiplos

# %%
import pandas as pd
import numpy as np

# %%
# Níveis de índice
outside = ["G1","G1","G1","G2","G2","G2"]
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside, inside))

# %%
hier_index
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
hier_index = pd.MultiIndex.from_tuples(hier_index)
hier_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df = pd.DataFrame(np.random.randn(6,2), index=hier_index, columns=['A','B'])
df
# Out:
#              A         B
# G1 1  1.090047  0.641424
#    2  0.302483 -0.370016
#    3  0.750347  1.172047
# G2 1 -0.386685 -0.828340
#    2  0.222878 -2.010728
#    3  0.555340  0.672455

# %%
df.loc['G1'].loc[2]
# Out:
# A    0.302483
# B   -0.370016
# Name: 2, dtype: float64

# %%
df.index.names = ['Grupo','Número']

# %%
df
# Out:
#                      A         B
# Grupo Número
# G1    1       1.090047  0.641424
#       2       0.302483 -0.370016
#       3       0.750347  1.172047
# G2    1      -0.386685 -0.828340
#       2       0.222878 -2.010728
#       3       0.555340  0.672455

# %%
df.xs('G1')
# Out:
#                A         B
# Número
# 1       1.090047  0.641424
# 2       0.302483 -0.370016
# 3       0.750347  1.172047

# %%
df.xs(1, level='Número')
# Out:
#               A         B
# Grupo
# G1     1.090047  0.641424
# G2    -0.386685 -0.828340
